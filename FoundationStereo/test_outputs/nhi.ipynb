# %%
import numpy as np
x = np.load('/home/nhinguyen/Desktop/OmniLRS/FoundationStereo/test_outputs/depth_meter.npy')
x
# Out:
# array([[ 0.       ,  0.       ,  0.       , ..., 14.3809185, 14.311285 ,
#         14.134463 ],
#        [ 0.       ,  0.       ,  0.       , ..., 14.351549 , 14.08404  ,
#         13.894095 ],
#        [ 0.       ,  0.       ,  0.       , ..., 14.3343935, 14.446801 ,
#         14.024886 ],
#        ...,
#        [ 0.       ,  0.       ,  0.       , ...,  1.8016133,  1.8068435,
#          1.815764 ],
#        [ 0.       ,  0.       ,  0.       , ...,  1.7989275,  1.7957926,
#          1.8102418],
#        [ 0.       ,  0.       ,  0.       , ...,  1.7927829,  1.7845842,
#          1.8072515]], dtype=float32)

# %%
for row in x:
    # print(', '.join([str(_) for _ in row]))
    print(np.max(row))
# Out:
# 16.101854
# 16.01303
# 15.902987
# 15.854514
# 15.871933
# 15.994104
# 16.087479
# 16.188555
# 15.979261
# 15.967016
# 15.927665
# 15.913819
# 16.240408
# 16.281496
# 16.262093
# 16.364393
# 16.301655
# 16.262938
# 16.46161
# 16.546047
# 16.391384
# 16.390184
# 16.489658
# 16.521528
# 16.430109
# 16.414433
# 16.480862
# 16.654335
# 16.675547
# 16.747002
# 16.774841
# 16.914488
# 16.51848
# 16.52387
# 16.601746
# 16.73326
# 16.64672
# 16.535221
# 16.496222
# 16.532166
# 16.483961
# 16.548878
# 16.7102
# 16.82776
# 16.740675
# 16.724682
# 16.47858
# 16.497675
# 16.834105
# 16.753931
# 16.958883
# 17.207663
# 16.74097
# 16.769321
# 16.940197
# 17.017586
# 17.03018
# 17.073603
# 17.116302
# 17.163946
# 17.087378
# 17.225046
# 17.079817
# 17.233995
# 17.245699
# 17.292038
# 17.500172
# 17.623737
# 17.355389
# 17.373852
# 17.28178
# 17.334356
# 17.802172
# 17.712965
# 17.729372
# 17.840307
# 17.449984
# 17.47463
# 17.406263
# 17.462545
# 18.169212
# 18.143955
# 18.203796
# 18.372498
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.imshow(x, cmap='viridis')
plt.colorbar()
plt.title('x Map')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(x, cmap='turbo')
plt.colorbar()
plt.title('Depth Map (Turbo)')
plt.axis('off')

plt.tight_layout()
plt.show()
